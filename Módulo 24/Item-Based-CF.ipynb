# %%
import pandas as pd

# %%
r_cols=['user_id', 'movie_id', 'rating']
ratings =pd.read_csv('./ml-100k/u.data', sep='\t', names=r_cols, usecols=range(3))
m_cols=['movie_id', 'title']
movies =pd.read_csv('./ml-100k/u.item', sep='|', names=m_cols, usecols=range(2), encoding='iso-8859-1')

ratings =pd.merge(movies, ratings)
ratings.head()
# Out:
#    movie_id             title  user_id  rating
# 0         1  Toy Story (1995)      308       4
# 1         1  Toy Story (1995)      287       5
# 2         1  Toy Story (1995)      148       4
# 3         1  Toy Story (1995)      280       4
# 4         1  Toy Story (1995)       66       3

# %%
userRatings = ratings.pivot_table(index=['user_id'],columns=['title'], values='rating')
userRatings.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# 5                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
corrMatrix = userRatings.corr()
corrMatrix.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        1.0           NaN
# 1-900 (1994)                                     NaN           1.0
# 101 Dalmatians (1996)                           -1.0           NaN
# 12 Angry Men (1957)                             -0.5           NaN
# 187 (1997)                                      -0.5           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)              -1.000000            -0.500000
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                   1.000000            -0.049890
# 12 Angry Men (1957)                    -0.049890             1.000000
# 187 (1997)                              0.269191             0.666667
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# ...

# %%
corrMatrix = userRatings.corr(method='pearson', min_periods=100)
corrMatrix.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        NaN           NaN
# 1-900 (1994)                                     NaN           NaN
# 101 Dalmatians (1996)                            NaN           NaN
# 12 Angry Men (1957)                              NaN           NaN
# 187 (1997)                                       NaN           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)                    NaN                  NaN
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                        1.0                  NaN
# 12 Angry Men (1957)                          NaN                  1.0
# 187 (1997)                                   NaN                  NaN
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# ...

# %%
# for movie in movies.iterrows():
#     print(f'{movie[1].title}')
import numpy as np
new_row = np.empty(userRatings.loc[1].shape[0])
new_row[:] = np.nan
# new_row = pd.DataFrame(np.nan, userRatings.loc[1].shape[0])
new_row[2] = 4.0
new_row[17] = 5.0
new_row[18] = 5.0
new_row[23] = 4.0
new_row[25] = 5.0
userRatings.loc[0] = new_row
myRatings = userRatings.loc[0].dropna()
myRatings
# Out:
# title
# 101 Dalmatians (1996)                    4.0
# Ace Ventura: Pet Detective (1994)        5.0
# Ace Ventura: When Nature Calls (1995)    5.0
# Adventures of Pinocchio, The (1996)      4.0
# Adventures of Robin Hood, The (1938)     5.0
# Name: 0, dtype: float64

# %%
simCandidates = pd.Series()
for i in range(0, len(myRatings.index)):
    print("Adding sims for " + myRatings.index[i] + "...")
    sims = corrMatrix[myRatings.index[i]].dropna()
    sims = sims.map(lambda x: x*myRatings[i])
    simCandidates = simCandidates._append(sims)

simCandidates.sort_values(inplace=True, ascending=False)
print(simCandidates.head(10))
# Out:
# Adding sims for 101 Dalmatians (1996)...
# Adding sims for Ace Ventura: Pet Detective (1994)...
# Adding sims for Ace Ventura: When Nature Calls (1995)...
# Adding sims for Adventures of Pinocchio, The (1996)...
# Adding sims for Adventures of Robin Hood, The (1938)...
# Marvin's Room (1996)    5.0
# Double Team (1997)      5.0
# Blown Away (1994)       5.0
# Mr. Magoo (1997)        5.0
# Soul Food (1997)        5.0
# Tom and Huck (1995)     5.0
# Apostle, The (1997)     5.0
# Eddie (1996)            5.0
# Palmetto (1998)         5.0
# Blood Beach (1981)      5.0
# dtype: float64

# %%
simCandidates = simCandidates.groupby(simCandidates.index).sum()

# %%
simCandidates.sort_values(inplace=True, ascending=False)
simCandidates.head(10)
# Out:
# Stupids, The (1996)                         20.897768
# House Party 3 (1994)                        14.518483
# Major Payne (1994)                          14.344345
# Oliver & Company (1988)                     14.298942
# Princess Caraboo (1994)                     14.022332
# Palmetto (1998)                             14.000000
# Anastasia (1997)                            13.851445
# Microcosmos: Le peuple de l'herbe (1996)    13.804953
# Solo (1996)                                 13.634458
# Celtic Pride (1996)                         13.197885
# dtype: float64
